# %% [markdown]
# # Objetivo
#
# Utilizar ferramentas Big Data para tratar e visualizar uma grande quantidade de dados de GPS

# %% [markdown]
# #Big Data Set de GTFS
#
# O website Kaggle possui um dataset de arquivos SPTRANS GTFS de vários dias compilados em um só. O compilado pode ser encontrado no seguinte link:
#
#  https://www.kaggle.com/joaofb/so-paulo-bus-system.
#
# Iremos utilizar este compilado para aplicar os procedentes conceitos de Big Data.

# %% [markdown]
# # Instalações

# %%
# !pip3 install pyspark
# !pip3 install dask
# !pip3 install dask[dataframe]
# !pip3 install pyproj
# !pip3 install datashader
# !pip3 install holoviews
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.6/dist-packages (3.0.1)
# Requirement already satisfied: py4j==0.10.9 in /usr/local/lib/python3.6/dist-packages (from pyspark) (0.10.9)
# Requirement already satisfied: dask in /usr/local/lib/python3.6/dist-packages (2.12.0)
# Requirement already satisfied: dask[dataframe] in /usr/local/lib/python3.6/dist-packages (2.12.0)
# Requirement already satisfied: fsspec>=0.6.0; extra == "dataframe" in /usr/local/lib/python3.6/dist-packages (from dask[dataframe]) (0.8.4)
# Requirement already satisfied: numpy>=1.13.0; extra == "dataframe" in /usr/local/lib/python3.6/dist-packages (from dask[dataframe]) (1.18.5)
# Requirement already satisfied: partd>=0.3.10; extra == "dataframe" in /usr/local/lib/python3.6/dist-packages (from dask[dataframe]) (1.1.0)
# Requirement already satisfied: toolz>=0.7.3; extra == "dataframe" in /usr/local/lib/python3.6/dist-packages (from dask[dataframe]) (0.11.1)
# Requirement already satisfied: pandas>=0.23.0; extra == "dataframe" in /usr/local/lib/python3.6/dist-packages (from dask[dataframe]) (1.1.4)
# Requirement already satisfied: locket in /usr/local/lib/python3.6/dist-packages (from partd>=0.3.10; extra == "dataframe"->dask[dataframe]) (0.2.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0; extra == "dataframe"->dask[dataframe]) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0; extra == "dataframe"->dask[dataframe]) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas>=0.23.0; extra == "dataframe"->dask[dataframe]) (1.15.0)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.6/dist-packages (3.0.0.post1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from pyproj) (2020.11.8)
# Requirement already satisfied: datashader in /usr/local/lib/python3.6/dist-packages (0.11.1)
# Requirement already satisfied: toolz>=0.7.4 in /usr/local/lib/python3.6/dist-packages (from datashader) (0.11.1)
# Requirement already satisfied: pyct[cmd]==0.4.6 in /usr/local/lib/python3.6/dist-packages (from datashader) (0.4.6)
# Requirement already satisfied: datashape>=0.5.1 in /usr/local/lib/python3.6/dist-packages (from datashader) (0.5.2)
# Requirement already satisfied: pandas>=0.24.1 in /usr/local/lib/python3.6/dist-packages (from datashader) (1.1.4)
# Requirement already satisfied: xarray>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from datashader) (0.15.1)
# Requirement already satisfied: param>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from datashader) (1.10.0)
# Requirement already satisfied: bokeh in /usr/local/lib/python3.6/dist-packages (from datashader) (2.1.1)
# Requirement already satisfied: dask[complete]>=0.18.0 in /usr/local/lib/python3.6/dist-packages (from datashader) (2.12.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from datashader) (1.18.5)
# Requirement already satisfied: pillow>=3.1.1 in /usr/local/lib/python3.6/dist-packages (from datashader) (7.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from datashader) (1.4.1)
# Requirement already satisfied: colorcet>=0.9.0 in /usr/local/lib/python3.6/dist-packages (from datashader) (2.0.2)
# Requirement already satisfied: numba!=0.49.*,!=0.50.*,>=0.37.0 in /usr/local/lib/python3.6/dist-packages (from datashader) (0.48.0)
# Requirement already satisfied: pyyaml; extra == "cmd" in /usr/local/lib/python3.6/dist-packages (from pyct[cmd]==0.4.6->datashader) (3.13)
# Requirement already satisfied: requests; extra == "cmd" in /usr/local/lib/python3.6/dist-packages (from pyct[cmd]==0.4.6->datashader) (2.23.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from datashape>=0.5.1->datashader) (2.8.1)
# Requirement already satisfied: multipledispatch>=0.4.7 in /usr/local/lib/python3.6/dist-packages (from datashape>=0.5.1->datashader) (0.6.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24.1->datashader) (2018.9)
# Requirement already satisfied: setuptools>=41.2 in /usr/local/lib/python3.6/dist-packages (from xarray>=0.9.6->datashader) (50.3.2)
# Requirement already satisfied: Jinja2>=2.7 in /usr/local/lib/python3.6/dist-packages (from bokeh->datashader) (2.11.2)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.6/dist-packages (from bokeh->datashader) (20.4)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.6/dist-packages (from bokeh->datashader) (5.1.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.6/dist-packages (from bokeh->datashader) (3.7.4.3)
# Requirement already satisfied: fsspec>=0.6.0; extra == "complete" in /usr/local/lib/python3.6/dist-packages (from dask[complete]>=0.18.0->datashader) (0.8.4)
# Requirement already satisfied: partd>=0.3.10; extra == "complete" in /usr/local/lib/python3.6/dist-packages (from dask[complete]>=0.18.0->datashader) (1.1.0)
# Requirement already satisfied: cloudpickle>=0.2.1; extra == "complete" in /usr/local/lib/python3.6/dist-packages (from dask[complete]>=0.18.0->datashader) (1.3.0)
# Requirement already satisfied: distributed>=2.0; extra == "complete" in /usr/local/lib/python3.6/dist-packages (from dask[complete]>=0.18.0->datashader) (2.30.1)
# Requirement already satisfied: llvmlite<0.32.0,>=0.31.0dev0 in /usr/local/lib/python3.6/dist-packages (from numba!=0.49.*,!=0.50.*,>=0.37.0->datashader) (0.31.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests; extra == "cmd"->pyct[cmd]==0.4.6->datashader) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests; extra == "cmd"->pyct[cmd]==0.4.6->datashader) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests; extra == "cmd"->pyct[cmd]==0.4.6->datashader) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests; extra == "cmd"->pyct[cmd]==0.4.6->datashader) (2020.11.8)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil->datashape>=0.5.1->datashader) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.7->bokeh->datashader) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging>=16.8->bokeh->datashader) (2.4.7)
# Requirement already satisfied: locket in /usr/local/lib/python3.6/dist-packages (from partd>=0.3.10; extra == "complete"->dask[complete]>=0.18.0->datashader) (0.2.0)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.6/dist-packages (from distributed>=2.0; extra == "complete"->dask[complete]>=0.18.0->datashader) (5.4.8)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from distributed>=2.0; extra == "complete"->dask[complete]>=0.18.0->datashader) (1.7.0)
# Requirement already satisfied: contextvars; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from distributed>=2.0; extra == "complete"->dask[complete]>=0.18.0->datashader) (2.4)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from distributed>=2.0; extra == "complete"->dask[complete]>=0.18.0->datashader) (2.0.0)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from distributed>=2.0; extra == "complete"->dask[complete]>=0.18.0->datashader) (1.0.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.6/dist-packages (from distributed>=2.0; extra == "complete"->dask[complete]>=0.18.0->datashader) (2.3.0)
# Requirement already satisfied: click>=6.6 in /usr/local/lib/python3.6/dist-packages (from distributed>=2.0; extra == "complete"->dask[complete]>=0.18.0->datashader) (7.1.2)
# Requirement already satisfied: immutables>=0.9 in /usr/local/lib/python3.6/dist-packages (from contextvars; python_version < "3.7"->distributed>=2.0; extra == "complete"->dask[complete]>=0.18.0->datashader) (0.14)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.6/dist-packages (from zict>=0.1.3->distributed>=2.0; extra == "complete"->dask[complete]>=0.18.0->datashader) (1.0.1)
# Requirement already satisfied: holoviews in /usr/local/lib/python3.6/dist-packages (1.13.5)
# Requirement already satisfied: panel>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from holoviews) (0.9.7)
# Requirement already satisfied: numpy>=1.0 in /usr/local/lib/python3.6/dist-packages (from holoviews) (1.18.5)
# Requirement already satisfied: pyviz-comms>=0.7.3 in /usr/local/lib/python3.6/dist-packages (from holoviews) (0.7.6)
# Requirement already satisfied: param<2.0,>=1.9.3 in /usr/local/lib/python3.6/dist-packages (from holoviews) (1.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from holoviews) (1.1.4)
# Requirement already satisfied: pyct>=0.4.4 in /usr/local/lib/python3.6/dist-packages (from panel>=0.8.0->holoviews) (0.4.6)
# Requirement already satisfied: markdown in /usr/local/lib/python3.6/dist-packages (from panel>=0.8.0->holoviews) (3.3.3)
# Requirement already satisfied: bokeh>=2.1 in /usr/local/lib/python3.6/dist-packages (from panel>=0.8.0->holoviews) (2.1.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from panel>=0.8.0->holoviews) (4.41.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->holoviews) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->holoviews) (2018.9)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown->panel>=0.8.0->holoviews) (2.0.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.6/dist-packages (from bokeh>=2.1->panel>=0.8.0->holoviews) (3.13)
# Requirement already satisfied: Jinja2>=2.7 in /usr/local/lib/python3.6/dist-packages (from bokeh>=2.1->panel>=0.8.0->holoviews) (2.11.2)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.6/dist-packages (from bokeh>=2.1->panel>=0.8.0->holoviews) (5.1.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.6/dist-packages (from bokeh>=2.1->panel>=0.8.0->holoviews) (3.7.4.3)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.6/dist-packages (from bokeh>=2.1->panel>=0.8.0->holoviews) (20.4)
# Requirement already satisfied: pillow>=4.0 in /usr/local/lib/python3.6/dist-packages (from bokeh>=2.1->panel>=0.8.0->holoviews) (7.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas->holoviews) (1.15.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown->panel>=0.8.0->holoviews) (3.4.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.7->bokeh>=2.1->panel>=0.8.0->holoviews) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging>=16.8->bokeh>=2.1->panel>=0.8.0->holoviews) (2.4.7)

# %% [markdown]
# # Download do Big Data Set de GTFS
#
# Referência: https://medium.com/analytics-vidhya/how-to-fetch-kaggle-datasets-into-google-colab-ea682569851a

# %%
# Monta o google drive no google colab

from google.colab import drive
drive.flush_and_unmount()
drive.mount('/content/gdrive')
# Out:
# Drive not mounted, so nothing to flush and unmount.
# Mounted at /content/gdrive

# %%
# Cria variavél de caminho do 
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/big_data/"

# %%
# %cd /content/gdrive/MyDrive/big_data/
# Out:
# /content/gdrive/MyDrive/big_data

# %%
# !kaggle datasets download -d joaofb/so-paulo-bus-system
# Out:
# Downloading so-paulo-bus-system.zip to /content/gdrive/My Drive/big_data
# 100% 697M/699M [00:06<00:00, 131MB/s]
# 100% 699M/699M [00:06<00:00, 107MB/s]

# %%
#unzipping the zip files and deleting the zip files
# !unzip \*.zip  && rm *.zip
# Out:
# Archive:  so-paulo-bus-system.zip
#   inflating: bus_position.csv
#   inflating: frequencies.csv
#   inflating: overview.csv
#   inflating: passengers.csv
#   inflating: routes.csv
#   inflating: shapes.csv
#   inflating: stop_times.csv
#   inflating: stops.csv
#   inflating: trips.csv

# %% [markdown]
# # Transform com PySpark
#
# Referência: http://www.filipyoo.com/plot-visualization-Hadoop-large-dataset-with-python-datashader/

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("GTFS with Dask").getOrCreate()

# %%
# O Arquivo Bus positions possui 2 gb de dados compilados do dia  28/04/2020 até o dia 06/05/2020.
dados = spark.read.csv('/content/gdrive/MyDrive/big_data/bus_position.csv', header=True,inferSchema=True)

# %%
# exibe o schema
dados.printSchema()
# Out:
# root
#  |-- index: integer (nullable = true)
#  |-- hr: string (nullable = true)
#  |-- c: string (nullable = true)
#  |-- cl: integer (nullable = true)
#  |-- lt0: string (nullable = true)
#  |-- lt1: string (nullable = true)
#  |-- qv: integer (nullable = true)
#  |-- p: integer (nullable = true)
#  |-- a: integer (nullable = true)
#  |-- ta: timestamp (nullable = true)
#  |-- py: double (nullable = true)
#  |-- px: double (nullable = true)
#  |-- id: integer (nullable = true)

# %%
dados.head(5)
# Out:
# [Row(index=0, hr='11:13', c='3063-10', cl=33021, lt0='TERM. SÃO MATEUS', lt1='GUAIANAZES', qv=2, p=31034, a=1, ta=datetime.datetime(2020, 4, 28, 14, 12, 17), py=-23.61408, px=-46.4765, id=1),
#  Row(index=0, hr='11:13', c='3063-10', cl=33021, lt0='TERM. SÃO MATEUS', lt1='GUAIANAZES', qv=2, p=31487, a=1, ta=datetime.datetime(2020, 4, 28, 14, 11, 30), py=-23.552765, px=-46.405838, id=2),
#  Row(index=1, hr='11:13', c='2712-10', cl=926, lt0='SHOP. METRÔ ITAQUERA', lt1='JD. SÃO NICOLAU', qv=3, p=45150, a=1, ta=datetime.datetime(2020, 4, 28, 14, 12, 41), py=-23.530886, px=-46.47826, id=3),
#  Row(index=1, hr='11:13', c='2712-10', cl=926, lt0='SHOP. METRÔ ITAQUERA', lt1='JD. SÃO NICOLAU', qv=3, p=45261, a=1, ta=datetime.datetime(2020, 4, 28, 14, 13, 1), py=-23.527357, px=-46.479187, id=4),
#  Row(index=1, hr='11:13', c='2712-10', cl=926, lt0='SHOP. METRÔ ITAQUERA', lt1='JD. SÃO NICOLAU', qv=3, p=45728, a=1, ta=datetime.datetime(2020, 4, 28, 14, 12, 26), py=-23.527357, px=-46.479187, id=5)]

# %%
dados.show()
# Out:
# +-----+-----+-------+-----+--------------------+--------------------+---+-----+---+-------------------+----------+----------+---+
# |index|   hr|      c|   cl|                 lt0|                 lt1| qv|    p|  a|                 ta|        py|        px| id|
# +-----+-----+-------+-----+--------------------+--------------------+---+-----+---+-------------------+----------+----------+---+
# |    0|11:13|3063-10|33021|    TERM. SÃO MATEUS|          GUAIANAZES|  2|31034|  1|2020-04-28 14:12:17| -23.61408|  -46.4765|  1|
# |    0|11:13|3063-10|33021|    TERM. SÃO MATEUS|          GUAIANAZES|  2|31487|  1|2020-04-28 14:11:30|-23.552765|-46.405838|  2|
# |    1|11:13|2712-10|  926|SHOP. METRÔ ITAQUERA|     JD. SÃO NICOLAU|  3|45150|  1|2020-04-28 14:12:41|-23.530886| -46.47826|  3|
# |    1|11:13|2712-10|  926|SHOP. METRÔ ITAQUERA|     JD. SÃO NICOLAU|  3|45261|  1|2020-04-28 14:13:01|-23.527357|-46.479187|  4|
# |    1|11:13|2712-10|  926|SHOP. METRÔ ITAQUERA|     JD. SÃO NICOLAU|  3|45728|  1|2020-04-28 14:12:26|-23.527357|-46.479187|  5|
# |    2|11:13|4313-10| 2173|TERM. PQ. D. PEDR...|TERM. CID. TIRADE...|  8|31259|  1|2020-04-28 14:12:37|-23.539164| -46.57057|  6|
# |    2|11:13|4313-10| 2173|TERM. PQ. D. PEDR...|TERM. CID. TIRADE...|  8|31244|  1|2020-04-28 14:12:15|-23.583939| -46.41498|  7|
# |    2|11:13|4313-10| 2173|TERM. PQ. D. PEDR...|TERM. CID. TIRADE...|  8|31283|  1|2020-04-28 14:12:22|-23.547401| -46.62979|  8|
# |    2|11:13|4313-10| 2173|TERM. PQ. D. PEDR...|TERM. CID. TIRADE...|  8|31023|  1|2020-04-28 14:12:46| -23.54987|-46.523865|  9|
# |    2|11:13|4313-10| 2173|TERM. PQ. D. PEDR...|TERM. CID. TIRADE...|  8|31235|  1|2020-04-28 14:12:34|-23.595713| -46.43733| 10|
# |    2|11:13|4313-10| 2173|TERM. PQ. D. PEDR...|TERM. CID. TIRADE...|  8|31240|  1|2020-04-28 14:12:24|-23.570503|-46.503933| 11|
# |    2|11:13|4313-10| 2173|TERM. PQ. D. PEDR...|TERM. CID. TIRADE...|  8|31261|  1|2020-04-28 14:12:50| -23.58334|-46.407215| 12|
# |    2|11:13|4313-10| 2173|TERM. PQ. D. PEDR...|TERM. CID. TIRADE...|  8|31105|  1|2020-04-28 14:12:51| -23.59631| -46.45563| 13|
# |    3|11:13|208V-10|32975|TERM. PQ. D. PEDR...|TERM. A. E. CARVALHO|  6|31142|  1|2020-04-28 14:12:21|-23.517572|-46.475784| 14|
# |    3|11:13|208V-10|32975|TERM. PQ. D. PEDR...|TERM. A. E. CARVALHO|  6|31445|  1|2020-04-28 14:12:31|-23.547686|-46.629257| 15|
# |    3|11:13|208V-10|32975|TERM. PQ. D. PEDR...|TERM. A. E. CARVALHO|  6|31187|  1|2020-04-28 14:12:29|-23.518082|-46.475685| 16|
# |    3|11:13|208V-10|32975|TERM. PQ. D. PEDR...|TERM. A. E. CARVALHO|  6|31281|  1|2020-04-28 14:12:33|-23.517815|-46.475735| 17|
# |    3|11:13|208V-10|32975|TERM. PQ. D. PEDR...|TERM. A. E. CARVALHO|  6|31111|  1|2020-04-28 14:12:24|-23.512732|-46.515335| 18|
# |    3|11:13|208V-10|32975|TERM. PQ. D. PEDR...|TERM. A. E. CARVALHO|  6|31113|  1|2020-04-28 14:12:56|-23.521612| -46.52768| 19|
# |    4|11:13|3746-10|33051|         METRÔ BELÉM|       JD. IMPERADOR|  7|51045|  1|2020-04-28 14:12:55|-23.542912|-46.588284| 20|
# +-----+-----+-------+-----+--------------------+--------------------+---+-----+---+-------------------+----------+----------+---+
# only showing top 20 rows

# %%
# Transformando o arquivo df em um parquet
dados.select(['ta', 'py', 'px']).write.parquet("/content/gdrive/MyDrive/big_data/bus_position.parquet")

# %% [markdown]
# # Big Data Dataframe com Dask
#
# Dask é o equivalente do pandas para Big Data em Python is the big data equivalent of Pandas in Python.
#
#
# Referência:
#
# https://examples.pyviz.org/nyc_taxi/nyc_taxi.html
#
# https://cgcooke.github.io/Blog/datashader/visualisation/pubg/2020/05/31/Visualising-PUBG-Deaths-With-Datashader.html

# %%
# carregando o parquet em um dask dataframe
import dask.dataframe as dd
import numpy as np

df = dd.read_parquet("/content/gdrive/MyDrive/big_data/bus_position.parquet")

# %%
df.head()
# Out:
#                    ta         py         px
# 0 2020-04-28 14:12:17 -23.614080 -46.476500
# 1 2020-04-28 14:11:30 -23.552765 -46.405838
# 2 2020-04-28 14:12:41 -23.530886 -46.478260
# 3 2020-04-28 14:13:01 -23.527357 -46.479187
# 4 2020-04-28 14:12:26 -23.527357 -46.479187

# %%
df['hour'] = df['ta'].dt.hour

# %%
df.head()
# Out:
#                    ta         py         px  hour
# 0 2020-04-28 14:12:17 -23.614080 -46.476500    14
# 1 2020-04-28 14:11:30 -23.552765 -46.405838    14
# 2 2020-04-28 14:12:41 -23.530886 -46.478260    14
# 3 2020-04-28 14:13:01 -23.527357 -46.479187    14
# 4 2020-04-28 14:12:26 -23.527357 -46.479187    14

# %%
df.dtypes
# Out:
# ta      datetime64[ns]
# py             float64
# px             float64
# hour             int64
# dtype: object

# %% [markdown]
# # View com Datashader
# Datashader é uma biblioteca muito eficiente para visualizar grandes quantidades de dados.

# %%
import datashader as ds
from datashader import transfer_functions as t
import holoviews.operation.datashader as hd
from datashader.colors import Hot
import numpy as np
import holoviews as hv
from holoviews import opts
from holoviews.element.tiles import StamenTerrain
hv.extension('bokeh')

shaded = hd.datashade(hv.Points(df, ['px', 'py']), cmap=Hot, aggregator=ds.count('hour'))
hd.dynspread(shaded, threshold=0.5, max_px=4).opts(bgcolor='black', xaxis=None, yaxis=None, width=900, height=700)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
